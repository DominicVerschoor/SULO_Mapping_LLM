# %%
from rdflib import Graph, Namespace, RDF, Literal, URIRef, RDFS
from urllib.parse import urlparse
import json

# %%
# Define namespaces
sphn = Namespace("https://www.biomedit.ch/rdf/sphn-schema/sphn#")
sulo = Namespace("https://aidava-dev.github.io/sulo/")
rdfs = Namespace("http://www.w3.org/2000/01/rdf-schema#")
xsd = Namespace("http://www.w3.org/2001/XMLSchema#")

# Load SPHN RDF file
g = Graph()
g.bind("sphn", sphn)
g.bind("sulo", sulo)
g.bind("rdfs", rdfs)
g.bind("xsd", xsd)
g.parse("turtles/sphn_classes.ttl", format="turtle")
print(f"{len(g)} Triples")
# Out:
# 2195 Triples

# %%
# Find all classes in the graph
sphn_classes = set()

for s in g.subjects(RDF.type, rdfs.Class):
    if str(s).startswith(str(sphn)):  # Only SPHN classes
        sphn_classes.add(s)

print("SPHN Classes found:")
for cls in sphn_classes:
    print(cls)
# Out:
# SPHN Classes found:
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Deprecated
# https://www.biomedit.ch/rdf/sphn-schema/sphn#samplePrimarycontainer
# https://www.biomedit.ch/rdf/sphn-schema/sphn#CardiacOutputMeasurement
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Measurement
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Quantity
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TumorStageAssessmentResult
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Chromosome
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MicroorganismIdentificationLabTestEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SingleNucleotideVariation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Catheter
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GenomicTranslocation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TumorSpecimen
# https://www.biomedit.ch/rdf/sphn-schema/sphn#FollowUp
# https://www.biomedit.ch/rdf/sphn-schema/sphn#adverseeventOutcome
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DataDetermination
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BodyHeightMeasurement
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SPHNConcept
# https://www.biomedit.ch/rdf/sphn-schema/sphn#NursingDiagnosis
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GeneticVariation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#sourcesystemCategory
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BodySite
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SwissSocioEconomicPosition
# https://www.biomedit.ch/rdf/sphn-schema/sphn#VitalStatus
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ICDODiagnosis
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Age
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Transcript
# https://www.biomedit.ch/rdf/sphn-schema/sphn#bodysurfaceareaCalculationmethod
# https://www.biomedit.ch/rdf/sphn-schema/sphn#RespiratoryRate
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MicrobiologyMicroscopyLabTestEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AssessmentComponent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MedicalProcedure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DrugArticle
# https://www.biomedit.ch/rdf/sphn-schema/sphn#HealthcareEncounter
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DataProvider
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AccessDevice
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MicroorganismIdentificationLabTest
# https://www.biomedit.ch/rdf/sphn-schema/sphn#CircumferenceMeasurement
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SampleProcessing
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MeasurementMethod
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BloodPressure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AssessmentResult
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GenomicInsertion
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Organism
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BilledDiagnosis
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Reference
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MicrobiologyBiomoleculePresenceLabTest
# https://www.biomedit.ch/rdf/sphn-schema/sphn#LabTestEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Assessment
# https://www.biomedit.ch/rdf/sphn-schema/sphn#genomicpositionCoordinateconvention
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Drug
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GenomicDelins
# https://www.biomedit.ch/rdf/sphn-schema/sphn#InhaledOxygenConcentration
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Location
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MicrobiologyMicroscopyLabTest
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SourceSystem
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Result
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MicrobiologyBiomoleculePresenceResult
# https://www.biomedit.ch/rdf/sphn-schema/sphn#therapeuticareaSpecialtyname
# https://www.biomedit.ch/rdf/sphn-schema/sphn#StandardOperatingProcedure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BodyHeight
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Intent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#CircumferenceMeasure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ReferenceSequence
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SourceData
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GenomicDuplication
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MicroorganismIdentificationResult
# https://www.biomedit.ch/rdf/sphn-schema/sphn#PharmaceuticalDoseForm
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DataRelease
# https://www.biomedit.ch/rdf/sphn-schema/sphn#LabTest
# https://www.biomedit.ch/rdf/sphn-schema/sphn#VariantNotation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#FluidBalance
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AllergyEpisode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SubjectPseudoIdentifier
# https://www.biomedit.ch/rdf/sphn-schema/sphn#CardiacOutput
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Birth
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Department
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AccessDevicePresence
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Discharge
# https://www.biomedit.ch/rdf/sphn-schema/sphn#semanticmappingPurpose
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DrugPrescription
# https://www.biomedit.ch/rdf/sphn-schema/sphn#CentralVenousPressure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#LabAnalyzer
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DiagnosticRadiologicExamination
# https://www.biomedit.ch/rdf/sphn-schema/sphn#RespiratoryRateMeasurement
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Laterality
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SequencingRun
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TumorGrade
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AntimicrobialSusceptibilityLabTestEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Circumference
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DataFile
# https://www.biomedit.ch/rdf/sphn-schema/sphn#FOPHProcedure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Biosample
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BodyWeightMeasurement
# https://www.biomedit.ch/rdf/sphn-schema/sphn#HomeAddress
# https://www.biomedit.ch/rdf/sphn-schema/sphn#NutritionIntake
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DeathStatus
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ResuscitationDirective
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BloodPressureMeasurement
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MicrobiologyMicroscopyResult
# https://www.biomedit.ch/rdf/sphn-schema/sphn#HeartRateMeasurement
# https://www.biomedit.ch/rdf/sphn-schema/sphn#OxygenAdministrationEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#OncologySurgery
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Allergy
# https://www.biomedit.ch/rdf/sphn-schema/sphn#LabResult
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Unit
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TumorGradeAssessmentResult
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GenomicPosition
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MedicalDevice
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GenomicDeletion
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BodyPosition
# https://www.biomedit.ch/rdf/sphn-schema/sphn#VariantDescriptor
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ReferenceInterpretation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Software
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GenomicInversion
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BodyWeight
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AdverseEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#insurancestatusCoveragetype
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Terminology
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Exposure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SemanticMapping
# https://www.biomedit.ch/rdf/sphn-schema/sphn#microbiologymicroscopyresultCellorganization
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hashAlgorithm
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Country
# https://www.biomedit.ch/rdf/sphn-schema/sphn#RadiotherapyProcedure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BilledProcedure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Biobanksample
# https://www.biomedit.ch/rdf/sphn-schema/sphn#HealthcarePrimaryInformationSystem
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Isolate
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ReferenceRange
# https://www.biomedit.ch/rdf/sphn-schema/sphn#CivilStatus
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ProblemCondition
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ExcludedDisorder
# https://www.biomedit.ch/rdf/sphn-schema/sphn#QualityControlMetric
# https://www.biomedit.ch/rdf/sphn-schema/sphn#CardiacIndex
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DeathDate
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Nationality
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GestationalAgeAtBirth
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Code
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Range
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GenomicTransposition
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BodyTemperature
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Interpretation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#FluidInputOutput
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TumorGradeAssessmentEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BirthDate
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ReferenceValue
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DrugAdministrationEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#FractionOfInspiredOxygen
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TNMClassification
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TumorStage
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GeneFusion
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AntimicrobialSusceptibilityLabTest
# https://www.biomedit.ch/rdf/sphn-schema/sphn#NucleotideSequence
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AdministrativeCase
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BodyMassIndex
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DataProcessing
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SequencingInstrument
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ValueSet
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ImagingProcedure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AdministrativeSex
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SimpleScore
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Sample
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TumorStageAssessment
# https://www.biomedit.ch/rdf/sphn-schema/sphn#OxygenSaturationMeasurement
# https://www.biomedit.ch/rdf/sphn-schema/sphn#adverseeventConsequences
# https://www.biomedit.ch/rdf/sphn-schema/sphn#CopyNumberVariation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ChromosomalLocation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ReferenceInterpretationResult
# https://www.biomedit.ch/rdf/sphn-schema/sphn#HeartRate
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Death
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TherapeuticArea
# https://www.biomedit.ch/rdf/sphn-schema/sphn#PhysiologicState
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TimeSeriesDataFile
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GenomicVariation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SequencingAssay
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Transplant
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Electrocardiogram
# https://www.biomedit.ch/rdf/sphn-schema/sphn#FOPHDiagnosis
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ImplantPresence
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Consent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#sampleFixationtype
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Diagnosis
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AssessmentEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Admission
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BodySurfaceArea
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Implant
# https://www.biomedit.ch/rdf/sphn-schema/sphn#InsuranceStatus
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Assay
# https://www.biomedit.ch/rdf/sphn-schema/sphn#OxygenSaturation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#OrganSupport
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Performer
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AntimicrobialSusceptibilityResult
# https://www.biomedit.ch/rdf/sphn-schema/sphn#datafileEncoding
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Comparator
# https://www.biomedit.ch/rdf/sphn-schema/sphn#ElectrocardiographicProcedure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TimePattern
# https://www.biomedit.ch/rdf/sphn-schema/sphn#AdministrativeGender
# https://www.biomedit.ch/rdf/sphn-schema/sphn#DataProviderInstitute
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Gene
# https://www.biomedit.ch/rdf/sphn-schema/sphn#LibraryPreparation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TobaccoExposure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TransplantPresence
# https://www.biomedit.ch/rdf/sphn-schema/sphn#BodyTemperatureMeasurement
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SequencingAnalysis
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Hash
# https://www.biomedit.ch/rdf/sphn-schema/sphn#MicrobiologyBiomoleculePresenceLabTestEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TumorGradeAssessment
# https://www.biomedit.ch/rdf/sphn-schema/sphn#SystemicArterialBloodPressure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#OncologyDiagnosis
# https://www.biomedit.ch/rdf/sphn-schema/sphn#sourcesystemPurpose
# https://www.biomedit.ch/rdf/sphn-schema/sphn#dataproviderCategory
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Substance
# https://www.biomedit.ch/rdf/sphn-schema/sphn#TumorStageAssessmentEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Allergen
# https://www.biomedit.ch/rdf/sphn-schema/sphn#CareHandling
# https://www.biomedit.ch/rdf/sphn-schema/sphn#Protein
# https://www.biomedit.ch/rdf/sphn-schema/sphn#GenePanel

# %%
# Extract all properties
sphn_properties = set()

for s in g.subjects(RDF.type, RDF.Property):
    if str(s).startswith(str(sphn)):
        sphn_properties.add(s)

print("SPHN Properties found:")
for prop in sorted(sphn_properties):
    print(prop)
# Out:
# SPHN Properties found:
# https://www.biomedit.ch/rdf/sphn-schema/sphn#dctermsconformsTo
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAcquisitionCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasActiveIngredient
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAdministrationRouteCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAdministrativeCase
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAdmission
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAgentCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAlgorithm
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAlleleOriginCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAllergen
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAlternateAllele
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasArticle
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAssessment
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAssociatedCountry
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAssociatedEvent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAverageInsertSize
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasAverageReadLength
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasBiobankName
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasBodySite
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasBreakpoint
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCalculationMethod
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCareHandling
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCategory
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCellCountEstimateCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCellMorphologyCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCellOrganization
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCertaintyCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasChemicalAgent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasChromosome
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCircumstanceCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCodingSystemAndVersion
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCollectionDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasComparator
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasComponent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasConditionCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasConsequences
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCoordinateConvention
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCountry
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCoverageType
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCreationDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasCurrentLocation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDataDetermination
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDataFile
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDataProvider
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDate
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDay
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDeath
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDegreeCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDeletedSequence
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDeletionBreakpoint
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDeliveryModeCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDepartment
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDerivedSequence
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDescription
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDeterminationDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDiastolicPressure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDischarge
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDistance
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDrug
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasDuration
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasEncoding
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasEnd
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasEndCytobandCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasEndDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasEnergyQuantity
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasEntryCount
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasEventDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasExact
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasExposure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasExtractionDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasFeatureLocation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasFirstAdministrationDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasFirstRecordDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasFixationType
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasFlowRate
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasFluidInputOutput
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasFocusGene
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasFormatCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasFractionOfInspiredOxygen
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasFractionsNumber
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasFrequency
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasGene
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasGenePanel
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasGenericName
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasGenomicPosition
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasGenomicVariation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasGestationalAge
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasGraftTypeCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasGroupSize
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasHash
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasIdentifier
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasInactiveIngredient
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasIncidenceDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasIndicationToStart
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasInput
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasInsertedSequence
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasInsertionBreakpoint
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasInsertionPoint
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasInstitutionCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasInstrument
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasIntendedInsertSize
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasIntendedReadDepth
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasIntendedReadLength
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasIntent
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasIntervention
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasKitCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasLabTest
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasLastAdministrationDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasLastReactionDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasLaterality
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasLibraryPreparation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasLiteralSequence
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasLowerLimit
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasManifestationCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasManufacturedDoseForm
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasMaterialTypeCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasMeanPressure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasMeanReadDepth
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasMedicalDevice
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasMethodCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasModeCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasMonth
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasName
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasNotation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasNucleotideSequence
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasNumberOfLeads
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasNumericalReference
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasOnsetDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasOrganism
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasOriginLocation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasOutcome
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasOutput
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasOutputCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasPerformer
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasPredecessor
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasPresenceCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasPrimaryContainer
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasPrimarySystem
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasProductCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasProtein
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasPurpose
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasQualityControlMetric
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasQuantity
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasRadiationQuantity
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasRange
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasRankCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasReactionTypeCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasReadCount
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasReasonToStopCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasRecordDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasReferenceAllele
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasReferenceSequence
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasRegularityCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasRegulatoryFeatureCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasRelativeTemporalityCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasReportDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasRestingPoint
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasResult
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasRouteCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSample
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSequenceLength
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSequencingInstrument
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSequencingRun
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSeverityCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSharedIdentifier
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSoftware
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSourceData
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSourceSystem
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSpecialtyName
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasStainingMethodCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasStainingResultCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasStandardGuideline
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasStandardOperatingProcedure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasStart
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasStartCytobandCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasStartDatetime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasStatusCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasStringValue
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSubjectAge
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSubjectPhysiologicState
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSubjectPseudoIdentifier
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSubstance
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSwissSocioEconomicPosition
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasSystolicPressure
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTargetEnrichmentKitCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTargetLocation
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTargetMolecule
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTemplateIdentifier
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTestKit
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTherapeuticArea
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTime
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTimePattern
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTimeToPositivity
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTotalCopyNumber
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTranscript
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTransplant
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTumorPurity
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasTypeCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasUniformResourceIdentifier
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasUniformResourceLocator
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasUnit
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasUpperLimit
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasValue
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasVerificationStatusCode
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasVersion
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasYear
# https://www.biomedit.ch/rdf/sphn-schema/sphn#hasZygosityCode

# %%
def extract_class_and_properties(g, sphn_class):
    result = {}
    result['class'] = str(sphn_class)
    result['label'] = str(g.value(sphn_class, rdfs.label))
    result['description'] = str(g.value(sphn_class, sphn.description))
    result['properties'] = []

    for prop in g.objects(sphn_class, sphn.properties):
        prop_label = str(g.value(prop, RDFS.label))
        prop_range = g.value(prop, RDFS.range)
        if isinstance(prop_range, Literal) and prop_range.value.startswith("https://"):
            prop_range_uri = URIRef(prop_range.value)
        else:
            prop_range_uri = prop_range

        result['properties'].append({
            'property': str(prop),
            'label': prop_label,
            'range': str(prop_range_uri)
        })

        # recursion if range is class:
        if prop_range_uri and (prop_range_uri, RDF.type, RDFS.Class) in g:
            result['properties'][-1]['range_details'] = extract_class_and_properties(g, prop_range_uri)

    return result

admin_case = extract_class_and_properties(g, sphn.AdministrativeCase)
allergy = extract_class_and_properties(g, sphn.Allergy)

# %% [markdown]
# ### Helper Methods

# %%
### Helper: Extract list of sulo classes from mappings (new data structure)
def extract_sulo_classes(mappings):
    sulo_class_list = []
    for m in mappings:
        sulo_class_list.extend(m["mapping"])
    return sulo_class_list

def get_sulo_property(domain_sulo_class, sulo_classes, sulo_data):
    sulo_class_list = extract_sulo_classes(sulo_classes)

    proposed_property = "sulo:hasPart"  # default fallback

    if set(sulo_class_list) == {"sulo:Role", "sulo:InformationObject"}:
        proposed_property = "sulo:hasParticipant"
    elif sulo_class_list == ["sulo:Role"]:
        proposed_property = "sulo:hasParticipant"
    elif sulo_class_list == ["sulo:InformationObject"]:
        proposed_property = "sulo:hasFeature"
    elif set(sulo_class_list) == {"sulo:Quality", "sulo:InformationObject"}:
        proposed_property = "sulo:hasFeature"
    elif set(sulo_class_list) == {"sulo:InformationObject", "sulo:SharedIdentifier"}:
        proposed_property = "sulo:hasFeature"
    elif sulo_class_list == ["sulo:Quantity"]:
        proposed_property = "sulo:hasFeature"
    elif sulo_class_list == ["sulo:Process"]:
        proposed_property = "sulo:hasPart"
    elif sulo_class_list == ["sulo:Object"]:
        proposed_property = "sulo:hasPart"
    elif sulo_class_list == ["sulo:Time"]:
        proposed_property = "sulo:atTime"
    elif sulo_class_list == ["sulo:SpatialObject"]:
        proposed_property = "sulo:isLocatedIn"

    # Validate against sulo_data
    domain_label = domain_sulo_class.split("/")[-1].replace(".html", "")
    sulo_class_info = next((item for item in sulo_data if item.get("SULO Class") == domain_label), None)
    if sulo_class_info:
        valid_properties = [p["property"] for p in sulo_class_info.get("usedProperties", [])]
        if proposed_property not in valid_properties:
            return "sulo:hasPart"
    return proposed_property

### Mapping pattern detector
def detect_mapping_pattern(domain_sulo_class, sulo_classes):
    sulo_class_list = extract_sulo_classes(sulo_classes)
    if sulo_class_list == ["sulo:InformationObject"]:
        return "SOLID"
    elif sulo_class_list == ["sulo:Role"]:
        return "PRO"
    elif set(sulo_class_list) == {"sulo:Role", "sulo:InformationObject"}:
        return "PRO+SOLID"
    else:
        return "DIRECT"

# %%
def get_var_name(uri):
    return uri.split("#")[-1]

def get_prefix(uri):
    if uri.startswith("https://www.biomedit.ch/rdf/sphn-schema/sphn#"):
        return "sphn"
    else:
        return "unknown"

def generate_where_block(class_data, mapping_data, parent_var=None):
    lines = []
    
    class_uri = class_data['class']
    class_short = get_var_name(class_uri)
    
    # Determine variable name
    if parent_var is None:
        parent_var = f"?{class_short}"
        target_class = mapping_data[class_uri]['targetClass']
        lines.append(f"{parent_var} a {target_class} .")
    
    # Process each property
    for prop in class_data['properties']:
        try:
            prop_uri = prop['property']
        except:
            prop_uri = prop
        prop_short = get_var_name(prop_uri)
        
        if class_uri not in mapping_data:
            continue  # no mapping for this class
        
        class_mapping = mapping_data[class_uri]
        if 'properties' not in class_mapping or prop_uri not in class_mapping['properties']:
            continue  # no mapping for this property
        
        prop_mapping = class_mapping['properties'][prop_uri]['mappings']
        
        for mapping in prop_mapping:
            target_var = f"?{prop_short}"
            if mapping['type'] == 'object':
                target_class_uri = class_mapping['properties'][prop_uri]['targetClass']
                next_class = mapping_data[target_class_uri]
                next_class['class'] = target_class_uri
                
                lines.append(" " * 2 + "\nOPTIONAL {")
                lines.append(" " * (2 + 2) + f"{parent_var} {get_prefix(prop_uri)}:{prop_short} {target_var} .")
                # lines.append(" " * (indent + 2) + f"{target_var} sphn:{target_class_short} .")
                #TODO: Generalize
                
                # Recurse if nested
                nested_block = generate_where_block(next_class, mapping_data, target_var)
                lines.extend(nested_block)
                
                lines.append(" " * 2 + "}")
            else:
                lines.append(" " * (4) + f"{parent_var} {get_prefix(prop_uri)}:{prop_short} {target_var} .")
    
    return lines

# Usage Example:
# Load your sulo_data.json once globally
with open("C:\GitHub\SULO_Mapping_LLM\data\sulo_data.json") as f:
    sulo_data = json.load(f)
with open("mapping_classes_2025_recursive.json") as f:
    mapping_table = json.load(f)

admin_case = extract_class_and_properties(g, sphn.AdministrativeCase)
where_block = generate_where_block(admin_case, mapping_table)
block="\n".join(where_block)

prefixes = """
PREFIX sphn: <https://www.biomedit.ch/rdf/sphn-schema/sphn#>
PREFIX sulo: <https://aidava-dev.github.io/sulo/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
"""

sparql_query = f"""{prefixes}

{block}
"""

with open(f"queries/AdministrativeCase_query.rq", "w") as f:
        f.write(sparql_query)

# %%
# transformation_query = open("queries/AdministrativeCase_query.rq").read()
transformation_query = open("queries/test.rq").read()

# Load SPHN RDF file
sphn_test_g = Graph()
sphn_test_g.bind("sphn", sphn)
sphn_test_g.bind("sulo", sulo)
sphn_test_g.bind("rdfs", rdfs)
sphn_test_g.bind("xsd", xsd)
sphn_test_g.parse("turtles/sphn_instance_administrativecase_v2025.ttl", format="turtle")

transformed_result = sphn_test_g.query(transformation_query)
sulo_graph = transformed_result.graph

sulo_graph.serialize(destination="output/administrative_case_transformed_sulo.ttl", format='turtle')
# Out:
# <Graph identifier=N941f6d97a69f4e229b3701345cc80a59 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Step	Description	Comments
# - 1	Load SPHN ontology (TTL)	You already have the SPHN TTL
# - 2	Extract classes and instances	Use rdflib/SPARQL to select instances of each SPHN class
# - 3	Create SPHN-to-SULO mapping table	For each SPHN class → identify corresponding SULO class
# - 4	Create property mapping table	For each SPHN property → identify corresponding SULO property
# - 5	Write transformation logic	Apply mapping tables to generate SULO triples
# - 6	Serialize output	Export generated SULO triples as TTL or JSON-LD

# %%
# Create a new graph for transformed data
# Define SPARQL transformation query
# This graph contains blank node structures that miss specific variable bindings

transformation_query = """
PREFIX sphn: <https://biomedit.ch/rdf/sphn-ontology/sphn#>
PREFIX sulo: <https://w3id.org/sulo/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX snomed: <http://snomed.info/id/>
PREFIX : <https://rdf.aidava.eu/resource/>

CONSTRUCT {
  # ?case a sphn:AdministrativeCase .
  # ?case sulo:hasPart [ a snomed:305056002;  sulo:isLocatedIn ?originLocation ;sulo:occursIn [ a sulo:Time; sulo:hasValue ?admissionDateTime ] ].
  # ?case sulo:hasPart [ a snomed:58000006;  sulo:isLocatedIn ?dischargeLocation ; sulo:occursIn [ a sulo:Time; sulo:hasValue ?dischargeDateTime ] ].
  # ?case sulo:isLocatedIn ?location.
  # ?case sulo:hasParticipant [ a :PatientRole; sulo:isFeatureOf ?subjectPseudoIdentifier ].
}

WHERE {
  OPTIONAL { ?case sphn:hasAdmissionDateTime ?admissionDateTime. }
  OPTIONAL { ?case sphn:hasOriginLocation ?originLocation. }

  OPTIONAL { ?case sphn:hasDischargeDateTime ?dischargeDateTime. }
  OPTIONAL { ?case sphn:hasLocation ?location. }

  OPTIONAL { ?case sphn:hasDischargeLocation ?dischargeLocation. }
  OPTIONAL { ?case sphn:hasSubjectPseudoIdentifier ?subjectPseudoIdentifier. }
}
"""

# Create a new graph for transformed data
transformed_g = g.query(transformation_query)
sulo_graph = transformed_g.graph
sulo_graph.bind("sphn", sphn)
sulo_graph.bind("sulo", sulo)
sulo_graph.bind("snomed", snomed)
sulo_graph.bind("aidava", aidava)

sulo_graph.serialize(destination="transformed_sulo.ttl", format='turtle')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 37
#      35 sulo_graph.bind("sphn", sphn)
#      36 sulo_graph.bind("sulo", sulo)
# ---> 37 sulo_graph.bind("snomed", snomed)
#      38 sulo_graph.bind("aidava", aidava)
#      40 sulo_graph.serialize(destination="transformed_sulo.ttl", format='turtle')
#
# NameError: name 'snomed' is not defined

# %% [markdown]
# ## Transform the RDF in SPHN to SULO

# %%
### TESTING

# Define SPARQL transformation query
transformation_query = """
PREFIX sphn: <https://biomedit.ch/rdf/sphn-ontology/sphn#>
PREFIX sulo: <https://w3id.org/sulo/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX snomed: <http://snomed.info/id/>
PREFIX : <https://rdf.aidava.eu/resource/>

CONSTRUCT {
  # ?case a sphn:AdministrativeCase .
  # ?case sulo:hasPart ?admission .

  # ?admission a snomed:305056002 .
  # ?admission sulo:isLocatedIn ?originLocation .
  # ?admission sulo:occursIn ?admission_time .
  # ?admission_time a sulo:Time .
  # ?admission_time sulo:hasValue ?admissionDateTime .

  # ?case sulo:hasPart [ a snomed:305056002;  sulo:isLocatedIn ?originLocation ;sulo:occursIn [ a sulo:Time; sulo:hasValue ?admissionDateTime ] ].
  # ?case sulo:hasPart [ a snomed:58000006;  sulo:isLocatedIn ?dischargeLocation ; sulo:occursIn [ a sulo:Time; sulo:hasValue ?dischargeDateTime ] ].
  # ?case sulo:isLocatedIn ?location.
  # ?case sulo:hasParticipant [ a :PatientRole; sulo:isFeatureOf ?subjectPseudoIdentifier ].
}

WHERE {
  # ?case a sphn:AdministrativeCase .
  BIND( IF( BOUND(?admissionDateTime) || BOUND(?originLocation) ,
      UUID(), # then: generate a UUID
       ""     # else: return a fallback string
    )
    AS ?uuid

   OPTIONAL {
    FILTER(BOUND(?admissionDateTime))
    BIND(IRI(CONCAT(STR(?case), "admission",STR(?admissionDateTime))) AS ?admission)
    #BIND(IRI(CONCAT(STR(?admission), "admission_time")) AS ?admission_time)
  }

  OPTIONAL { ?case sphn:hasAdmissionDateTime ?admissionDateTime. }
  OPTIONAL { ?case sphn:hasOriginLocation ?originLocation. }

  # OPTIONAL { ?case sphn:hasDischargeDateTime ?dischargeDateTime. }
  # OPTIONAL { ?case sphn:hasLocation ?location. }

  # OPTIONAL { ?case sphn:hasDischargeLocation ?dischargeLocation. }
  # OPTIONAL { ?case sphn:hasSubjectPseudoIdentifier ?subjectPseudoIdentifier. }
}
"""

# Create a new graph for transformed data
transformed_g = g.query(transformation_query)
sulo_graph = transformed_g.graph
sulo_graph.bind("sphn", sphn)
sulo_graph.bind("sulo", sulo)
sulo_graph.bind("snomed", snomed)
sulo_graph.bind("aidava", aidava)

sulo_graph.serialize(destination="transformed_sulo.ttl", format='turtle')
# Out:
# <Graph identifier=N2cf4672d6bb644948a1c7e5ccd167332 (<class 'rdflib.graph.Graph'>)>

# %%
# Define SPARQL query
query_x = """
PREFIX sphn: <https://biomedit.ch/rdf/sphn-ontology/sphn#>
PREFIX sulo: <https://w3id.org/sulo/>
PREFIX snomed: <http://snomed.info/id/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?case ?admissionDateTime
WHERE {
   # ?case a sphn:AdministrativeCase .
   # ?case sulo:hasPart ?admission_process .
   # ?admission_process a snomed:305056002 .
   # ?admission_process sulo:occursIn ?admissionDateTime .
}
"""

# %%
transformed_g = Graph()
transformed_g.parse("transformed_sulo.ttl", format="turtle")
# Out:
# <Graph identifier=Na7b418e0d0de408aac5a3089a8e7b9f6 (<class 'rdflib.graph.Graph'>)>

# %%
# Run query on transformed graph
results = transformed_g.query(query_x)

# Print results
for row in results:
    print(f"Visit: {row}")
# Out:
# Visit: (rdflib.term.URIRef('https://rdf.aidava.eu/resource/AdministrativeCase/1503'), rdflib.term.BNode('nf0dfeac93a4844e3b7becd5d9562289fb4'))
# Visit: (rdflib.term.URIRef('https://rdf.aidava.eu/resource/AdministrativeCase/2604'), rdflib.term.BNode('nf0dfeac93a4844e3b7becd5d9562289fb9'))

# %%
sulo2sphnv2025 = """
PREFIX sphn: <https://biomedit.ch/rdf/sphn-ontology/sphn#>
PREFIX sulo: <https://w3id.org/sulo/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX snomed: <http://snomed.info/id/>
PREFIX : <https://rdf.aidava.eu/resource/>

CONSTRUCT {
  # ?case a sphn:AdministrativeCase .

  # ?case sphn:admission ?admission .
  # ?admission a sphn:Admission.
  # ?admission sphn:hasDateTime ?admissionDateTime .
  # ?admission sphn:hasOriginLocation ?originLocation .

  # ?case sphn:discharge ?discarge .
  # ?discarge a sphn:Discharge .
  # ?discarge sphn:hasDateTime ?dischargeDateTime .
  # ?discarge sphn:hasTargetLocation ?targetLocation .
}
WHERE {
    # ?case a sphn:AdministrativeCase .
    OPTIONAL {
      # ?case sulo:hasPart ?admission .
      # ?admission a snomed:305056002 .
      OPTIONAL {
        # ?admission sulo:occursIn ?time .
        # ?time a sulo:Time .
        # ?time sulo:hasValue ?admissionDateTime .
      }
      OPTIONAL {
        # ?admission sulo:isLocatedIn ?originLocation .
      }
    }
    OPTIONAL {
      # ?case sulo:hasPart ?discharge .
      # ?discharge a snomed:58000006 .
      OPTIONAL {
        # ?discharge sulo:occursIn ?time .
        # ?time a sulo:Time .
        # ?time sulo:hasValue ?dischargeDateTime .
      }
      OPTIONAL {
        # ?discharge sulo:isLocatedIn ?targetLocation .
      }
    }


}
"""

results = transformed_g.query(sulo2sphnv2025)
graph = results.graph
graph.bind("sphn", sphn)
graph.bind("sulo", sulo)
graph.bind("snomed", snomed)
graph.bind("aidava", aidava)
graph.serialize(destination="sulo2sphnv2025.ttl", format='turtle')
# Out:
# <Graph identifier=Nf416864f927749c2bfd967629b15b32c (<class 'rdflib.graph.Graph'>)>
